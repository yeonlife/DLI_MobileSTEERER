# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/STEERER/STEERER
# Out:
# /content/drive/MyDrive/STEERER/STEERER

# %%
! git init
! git config --global user.email "yeonlife17@gmail.com"
! git config --global user.name "yeonlife"
! git add .
! git commit -m "mobiletnet"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/STEERER/STEERER/.git/
# [main 8facf80] first commit
#  67 files changed, 6 insertions(+), 4 deletions(-)
#  create mode 100644 STEERER_train.ipynb
#  create mode 100644 github push.ipynb
#  create mode 100644 lib/core/__pycache__/criterion.cpython-310.pyc
#  rewrite lib/datasets/__pycache__/__init__.cpython-310.pyc (96%)
#  create mode 100644 lib/datasets/utils/__pycache__/collate.cpython-310.pyc
#  rewrite lib/models/backbones/__pycache__/__init__.cpython-310.pyc (67%)
#  create mode 100644 lib/models/backbones/hrnet/__pycache__/hrnet_config.cpython-310.pyc
#  create mode 100644 lib/models/heads/__pycache__/head_selector.cpython-310.pyc
#  create mode 100644 lib/models/heads/__pycache__/moe.cpython-310.pyc
#  create mode 100644 lib/solver/__pycache__/__init__.cpython-310.pyc
#  create mode 100644 lib/solver/__pycache__/build.cpython-310.pyc
#  create mode 100644 lib/solver/__pycache__/lr_scheduler.cpython-310.pyc
# ...

# %%
! git remote remove origin

# %%
! git remote add origin https://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@github.com/yeonlife/DLI_STEERER_Baseline.git

# %%
! git remote -v
# Out:
# origin	https://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@github.com/yeonlife/DLI_STEERER_Baseline.git (fetch)
# origin	https://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@github.com/yeonlife/DLI_STEERER_Baseline.git (push)

# %%
! git push -u origin main
# Out:
# Enumerating objects: 1208, done.
# Counting objects: 100% (1208/1208), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (609/609), done.
# Writing objects: 100% (1208/1208), 7.49 MiB | 15.81 MiB/s, done.
# Total 1208 (delta 640), reused 1081 (delta 592), pack-reused 0
# remote: Resolving deltas: 100% (640/640), done.
# To https://github.com/yeonlife/DLI_STEERER_Baseline.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
